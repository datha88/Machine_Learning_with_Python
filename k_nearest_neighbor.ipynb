# %% [markdown]
# # K-Nearest Neighbor
#
# Goal of this problem set is to implement several algorithms from scratch.

# %%
# Importing relevant libraries
import IPython
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt  
import sklearn

# %% [markdown]
# ---
#
# ## Introduction to the assignment
#
# For this assignment, you will be using the [Boston Housing Prices Data Set](http://archive.ics.uci.edu/ml/datasets/Housing).  Please read about the dataset carefully before continuing.  Use the following commands to load the dataset:

# %%
from sklearn.datasets import load_boston
# Loading the boston dataset
bdata = load_boston()

# %% [markdown]
# The following commands will provide some basic information about the shape of the data:

# %%
# Basic information on the dataset
print bdata.keys()
print bdata.feature_names
print bdata.data.shape
print bdata.target.shape
print type(bdata)
# Out:
# ['data', 'feature_names', 'DESCR', 'target']
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# (506L, 13L)
# (506L,)
# <class 'sklearn.datasets.base.Bunch'>

# %%
# Converting the bunch datset to pandas dataframe structure
df = pd.DataFrame(bdata.data)
df['13'] = bdata.target
df.columns = ['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','b','lstat','medv']

# %% [markdown]
# ---
#
# ## Part 1: Descriptive analysis
#
# Before beginning the "real" work, dig into the data a bit do see what you're dealing with.  If you're new to analyzing data in Python, please make sure to read the relevant readings linked to on Canvas before beginning (for instance, [this one](https://github.com/jrjohansson/scientific-python-lectures)).
#
# ### 1.1: Histogram of housing prices
#
# Below you will find some very basic code to make a very basic histogram of median housing prices (the "target" variable) for your dataset.  Your first task is to make this graph look pretty by doing the following:
#
# 1. Add appropriate labels to the x and y axes, make sure to include units
# 2. Change the bin width on the histogram to be $1000
# 3. Remove the axes on the top and right side of the plot window
# 4. Change the color of the bars to be green, and remove the black borders from the bars

# %%
# For plotting inline
# %matplotlib inline
#Setting figure size
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18, 10)
ax = plt.subplot(111)
# Making histogram of median housing prices
ax.hist(df.medv,color='g',bins=45,edgecolor='none')
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Marking Legends
plt.title("Median Housing Prices Histogram")
plt.xlabel("Housing prices")
plt.ylabel("Frequency")
plt.axes
plt.show()

# %% [markdown]
# ### 1.2: Scatter plot of housing prices and crime
#
# Use matplotlib to create a scatter plot that shows the relationship between the median value of the home (y-axis) and the per-capita crime rate (x-axis).  Properly label your axes, and make sure that your graphic looks polished and professional.

# %%
# For plotting inline
# %matplotlib inline  
# Setting figure size
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18, 10)
# Creating scatterplot
plt.scatter(df.crim,df.medv,color='b')
# Marking legends
plt.title("Median Housing Vs Crime rate")
plt.xlabel("Crime rate")
plt.ylabel("Median Housing value")
plt.show()

# %% [markdown]
# ### 1.3 Create your own (creative and effective) visualization
#
# Use another type of graph or chart to illustrate an interesting pattern in the data.  Be creative in your visualization, and make sure to produce a "publication-quality" graph.  Points will be given for useful and creative graphs; points will be deducted for confusing issues like unlabeled axes.  If you're new to data visualization, [this guide](http://pubs.aeaweb.org/doi/pdfplus/10.1257/jep.28.1.209) is a good place to start.

# %%
# For plotting inline
# %matplotlib inline 
# Setting figure size
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18, 10)
# Creating scatterplot
plt.scatter(df.crim,df.rm,color='g',edgecolor='black')
# Marking legends
plt.title("Relationship between Average number of Rooms(rm) and Crime rate(crim)")
plt.xlabel("Crime rate")
plt.ylabel("Average number of Rooms")
plt.show()

# %% [markdown]
# ---
#
# ## Part 2: Experimental Setup
#
# The goal of the next few sections is to design an experiment to predict the median home value for an instance in the data.
#
# ### 2.1 Begin by writing a function to compute the Root Mean Squared Error for a list of numbers
#
# You can find the sqrt function in the Numpy package. Furthermore the details of RMSE can be found on [Wikipedia](http://en.wikipedia.org/wiki/Root-mean-square_deviation)

# %%
"""
Function
--------
compute_rmse

Given two arrays, one of actual values and one of predicted values,
compute the Root Mean Squared Error

Parameters
----------
predictions : array
    Array of numerical values corresponding to predictions for each of the N observations

yvalues : array
    Array of numerical values corresponding to the actual values for each of the N observations

Returns
-------
rmse : int
    Root Mean Squared Error of the prediction

Example
-------
>>> print compute_rmse((2,2,3),(0,2,6)
2.0816
"""
import operator
def compute_rmse(predictions, yvalues):
    # initialising rmse as zero
    rmse = 0    
    # finding the square of the differences
    sq = np.square(map(operator.sub, predictions, yvalues))
    # computing rmse
    rmse = np.sqrt(sum(sq)/float(len(predictions)))
    return rmse

# computing rmse as given in the example
print compute_rmse((2,2,3),(0,2,6))
# Out:
# 2.08166599947

# %% [markdown]
# ### 2.2 Divide your data into training and testing datasets
#
# Randomly select 66% of the data and put this in a training dataset (call this "bdata_train"), and place the remaining 34% in a testing dataset (call this "bdata_test")

# %%
# Finding 66% of the boston dataset
train_qty = int(round(0.66*len(df.index)))
# Randomly choosing 66% of the data as training data
bdata_train = df.sample(n=train_qty,random_state=13579)
# Finding indexes not in training datset
b = set(bdata_train.index)
d = set(df.index)
a = d.difference(b)
# Creating test dataset
bdata_test = df.ix[a,:]

# %% [markdown]
# ### 2.3 Use a very bad baseline for prediction, and compute RMSE
#
# Create a model that predicts, for every observation x_i, that the median home value is the average (mean) of the median values for all instances in the training set.  Compute the RMSE on the training set.  Now compute the RMSE on the test data set (but use the model you trained on the training set!).  How does RMSE compare for training vs. testing datasets? Is this what you expected, and why?

# %%
# creating predicted values based on mean of training dataset
pred_train = np.empty(len(bdata_train.index))
pred_train.fill(bdata_train.medv.mean())
# computing training rmse of predicted values and actual values from training data
train_rmse = compute_rmse(pred_train,bdata_train.medv)
print train_rmse

# creating predicted values based on mean of training dataset
pred_test = np.empty(len(bdata_test.index))
pred_test.fill(bdata_train.medv.mean())
# computing test rmse of predicted values and actual values from testing data
test_rmse = compute_rmse(pred_test,bdata_test.medv)
print test_rmse
# Out:
# 8.57443441541
# 10.3092622563

# %% [markdown]
# The RMSE of the training dataset is much better than the test dataset. This is expected as this is a very bad baseline and the model tries to predict the test datset solely on the basis of training dataset. Hence, the RMSE for the test datset is expected to much larger than the training dataset.

# %% [markdown]
# ---
#
# ## Part 3: Nearest Neighbors

# %% [markdown]
# ### 3.1 Nearest Neighbors: Distance function
# Let's try and build a machine learning algorithm to beat the "Average Value" baseline that you computed above.  Soon you will implement the Nearest Neighbor algorithm, but first you need to create a distance metric to measure the distance (and similarity) between two instances.  Write a generic function to compute the L-Norm distance (called the [*p*-norm](http://en.wikipedia.org/wiki/Norm_(mathematics) distance on Wikipedia). Verify that your function works by computing the Euclidean distance between the points (3,4) and (6,8).

# %%
"""
Function
--------
distance

Given two instances and a value for L, return the L-Norm distance between them

Parameters
----------
x1, x2 : array
    Array of numerical values corresponding to predictions for each of the N observations

L: int
    Value of L to use in computing distances

Returns
-------
dist : int
    The L-norm distance between instances

Example
-------
>>> print distance((3,4),(6,8),2)
5

"""
def distance(x1, x2, L):
    # computing difference 
    diff = map(operator.sub, x1, x2)
    # raising to the power of L
    power = np.power(diff, L)
    # finding sum
    sumx = reduce(operator.add, power)
    # finding Lth root of as the distance
    dist = (sumx)**(1./L)
    return dist

# Examples to try the function
print distance((3,4),(6,8),2)
print distance((3,4,5),(6,8,3),2)
# Out:
# 5.0
# 5.38516480713

# %% [markdown]
# ### 3.2 Basic Nearest Neighbor algorithm
#
# Now things get fun.  Your task is to implement a basic nearest neighbor algorithm from scratch.  Your simple model will use two input features (CRIM and RM) and a single output (MEDV).  In other words, you are modelling the relationship between median home value and crime rates and house size.
#
# Use your training data (bdata_train) to "fit" your model, although as you know, with Nearest Neighbors there is no real training, you just need to keep your training data in memory.  Write a function that predicts, for each instance in the testing data (bdata_test), the median home value using the nearest neighbor algorithm we discussed in class.  Since this is a small dataset, you can simply compare your test instance to every instance in the training set, and return the MEDV value of the closest training instance.  Have your function take L as an input, where L is passed to the distance function.
#
# Compute the RMSE for the Nearest Neighbor predictions on the test set, using the Euclidean distance.  Report an estimate of the total time taken by your code to predict the nearest neighbors for all the values in the test data set.

# %%
"""
Function
--------
nneighbor

Given training dataset, test dataset, features and L, compute the rmse using nearest neighbor algorithm

Parameters
----------
train : Pandas DataFrame
    DataFrame containing the training data

test : Pandas DataFrame
    DataFrame containing the test data

features : list
    list of columns that are used as input features to fit the model

L : int
    numeric value that is used in calculating Euclidean distance    
Returns
-------
rmse : int
    Root Mean Squared Error of the prediction

"""
# importing time
import time
def nneighbor(train,test,features,L):
    # starting time 
    start_time = time.time()
    # initialising rmse value as zero
    rmse = 0
    # dataframe to store the distance matrix 
    dist_df = pd.DataFrame(index=test.index,columns=train.index)    
    # Loop to calculate the distance between every datapoiint in test to every datapoint in train 
    for i,rowi in test.iterrows():       
        for j,rowj in train.iterrows():            
            dist_df.ix[i,j] = distance(list(rowi[features]),list(rowj[features]),L) 
    # dataframe to store the neighbor             
    min_arr = pd.DataFrame(index=test.index,columns=['neighbor']) 
    # loop to compute the minimum distance datapoint as the neighbor
    for i,row in dist_df.iterrows():       
        min_arr.ix[i,'neighbor'] = row.idxmin()
    # getting predicted and actual values         
    y_est = train.ix[list(min_arr.ix[:,'neighbor']),'medv'].copy()
    y_true = test.medv.copy()
    # computing rmse on predicted and actual values
    rmse = compute_rmse(np.array(y_est),np.array(y_true))
    # printing time taken for the algorithm
    print "Time taken: " + str(round(time.time() - start_time,2)) + " seconds"    
    return rmse
# calculating nearest neighbor for train and test data on features crim and rm with L as 2
nn = nneighbor(bdata_train,bdata_test,[0,5],2)
print "Rmse for nearest neighbor predictions-",nn
# Out:
# Time taken: 24.36 seconds
# rmse for nearest neighbor predictions  7.40172041598

# %% [markdown]
# ### 3.3 Results and Normalization
#
# If you were being astute, you would have noticed that we never normalized our features -- a big no-no with Nearest Neighbor algorithms.  Write a generic normalization function that takes as input an array of values for a given feature, and returns the normalized array (subtract the mean and divide by the standard deviation).
#
# Re-run the Nearest Neighbor algorithm on the normalized dataset (still just using CRIM and RM as input), and compare the RMSE from this method with your previous RMSE evaluations.
#
# *NOTE*: To normalize properly, best practice is to compute the mean and standard deviation on the training set, and use these values to normalize the testing dataset. However, for this problem set, it is okay if you separately normalize each dataset using the respective mean and standard deviation.

# %%
"""
Function
--------
normalize

Given a particular series, normalize it using the mean and standard deviation

Parameters
----------
raw_data : Pandas Series
    Series containing the raw data
    
Returns
-------
normalized_data : Pandas Series
    Series with normalized data

"""
def normalize(raw_data):
    # computing mean
    avg = raw_data.mean()
    # computing standard deviation
    sd = np.std(raw_data)
    # series for storing the normalized data
    normalized_data = pd.Series(index=raw_data.index)    
    # loop for converting raw data to normalized data
    for i,value in raw_data.iteritems():  
        # subtracting mean and then dividing standard deviation for each value
        x = (value - avg)/sd
        normalized_data = normalized_data.set_value(i, x)
    return normalized_data

# dataframes to store normalized train and test dataset
n_train = bdata_train.copy(deep=True)
n_test = bdata_test.copy(deep=True)
# looping through each column of train and test dataset
for i in n_train.columns:
    n_train.ix[:,i] = normalize(n_train.ix[:,i])
for i in n_test.columns:
    n_test.ix[:,i] = normalize(n_test.ix[:,i])    
# computing rmse for normalized data using nearest neighbor algorithm    
n2 = nneighbor(n_train,n_test,[0,5],2)
print "Rmse for nearest neighbor predictions on normalized data ",n2
# Out:
# Time taken: 24.58 seconds
# rmse for nearest neighbor predictions on normalized data  0.77856906683

# %% [markdown]
# The rmse obtained after normalization is 0.78 which is very low comapred to rmse we obtained using regular(non-normalized) dataset, which is 7.4.The rmse value is much lower when data is normalized as normalization helps in adjusting different features to the common scale.

# %% [markdown]
# ### 3.4 Optimization
#
# A lot of the decisions we've made so far have been arbitrary.  Try to increase the performance of your nearest neighbor algorithm by adding features that you think might be relevant, and by using different values of L in the distance function.  Try a model that uses a different set of 2 features, then try at least one model that uses more than 4 features, then try using a different value of L.  If you're having fun, try a few different combinations of features and L!
#
# What combination of features and distance function provide the lowest RMSE?  Do your decisions affect the running time of the algorithm?

# %%
# Computing nearest neighbor for more number of features
n4 = nneighbor(n_train,n_test,[0,4,5,7,10],2)
print "Rmse for features(crim,nox,rm,dis,ptratio) -",n4
# Changing features
n5 = nneighbor(n_train,n_test,[4,7],2)
print "Rmse for nox and dis -",n5

# Changing value of L
print "Rmse for crim and rm & L=2 -",n2
n6 = nneighbor(n_train,n_test,[0,5],4)
print "Rmse for crim and rm & L=4 -",n6
n7 = nneighbor(n_train,n_test,[0,5],8)
print "Rmse for crim and rm & L=8 -",n7
n8 = nneighbor(n_train,n_test,[0,5],16)
print "Rmse for crim and rm & L=16 -",n8
# Out:
# Time taken: 23.94 seconds
# Rmse for features(crim,nox,rm,dis,ptratio) - 0.831064237487
# Time taken: 28.45 seconds
# Rmse for nox and dis - 1.42719669394
# Rmse for crim and rm & L=2 - 0.77856906683
# Time taken: 24.72 seconds
# Rmse for crim and rm & L=4 - 0.774351410488
# Time taken: 23.64 seconds
# Rmse for crim and rm & L=8 - 0.837283528123
# Time taken: 25.1 seconds
# Rmse for crim and rm & L=16 - 0.84515158014

# %% [markdown]
# The rmse increases when the features are changed from crime rate and housing size. The rmse reduces at first when L is changed from 2 to 4. Then rmse keeps increasing as L increases from 4 to 16.
#
# The lowest rmse is obtained when the crim and rm are taken as input features and L value is 4. As L increases, the time taken to compute rmse using nearest neighbor algorithm also increases. It was also observed that when the number of input features are increased to 5, the time taken by the algorithm reduces slightly.

# %% [markdown]
# ### 3.5 Cross-Validation
#
# The more you tinkered with your features and distance function, the higher the risk that you overfit your training data.  To prevent this sort of overfitting, you need to use cross-validation (see K-fold [cross-validation](http://en.wikipedia.org/wiki/Cross-validation_(statistics)).  Here you must implement a simple k-fold cross-validation algorithm yourself.  The function you write here will be used several more times in this problem set, so do your best to write efficient code! (Note that the sklearn package has a built-in [K-fold](http://scikit-learn.org/stable/modules/cross_validation.html#cross-validation) iterator -- you should *not* be invoking that or any related algorithms in this section of the problem set.)
#
# Use 10-fold cross-validation and report the average RMSE for Nearest Neighbors using Euclidean distance with CRIM and RM input features, as well as the total running time for the full run of 10 folds.  In other words, randomly divide your dataset into 10 equally-sized samples, and for each of 10 iterations (the "folds"), use 9 samples as "training data" (even though there is no training in k-NN!), and the remaining 1 sample for testing.  Compute the RMSE of that particular test set, then move on to the next iteration.  Report the average RMSE across the 10 iterations.

# %%
"""
Function
--------
cross_validation

Given a data and kfold value, perform the k-fold cross validation on the data

Parameters
----------
kfold : int
    numeric value indicating the number of folds for cross validation

data : Pandas DataFrame
    DataFrame containing training dataset
    
Returns
-------
avg_rmse : int 
    The average rmse value across k-fold cross validation

"""
np.random.seed(seed=13579)

def cross_validation(kfold,data):
    start_time = time.time()    
    # series for storing rmse for each fold
    rmse = pd.Series(index=range(kfold))
    # Finding the number of values in each subsample
    n = (len(data))/kfold       
        
    d = data.copy()
    # Choosing only the number of rows that are evenly divided within train and test dataset 
    # Ignoring a few datapoints so that each subsample has equal number of datapoints
    d = data.head(n*kfold)    
    # Dataframe for storing the indexes for each subsample as a row    
    subsamples = pd.DataFrame(index=range(kfold),columns=range(n))    
    
    ind = pd.Series(d.index.values.copy())    
    # Randomly shuffling indexes
    np.random.shuffle(ind)       
    i=0   
    rowi = 0
    # Loop to create each row as a subsample
    while((i+n)<len(data)):
        subsamples.iloc[rowi,:] = list(ind.iloc[i:(i+n)])
        i = i+n
        rowi = rowi+1         
    
    for i in range(kfold):
        # choosing one of the subsample as test
        test_ind = subsamples.iloc[i,:]       
        # finding indexes that are not in test
        b = set(test_ind)
        c = set(d.index)
        a = c.difference(b)
        # creating the train and test dataset
        train = d.ix[a,:].copy()
        test = d.ix[b,:].copy()    
        
        # computing rmse using nearest neighbor
        n = nneighbor(train,test,[0,5],2) 
        # storing rmse for each fold
        rmse = rmse.set_value(i, n)  
    
    # computing average rmse across k-fold
    avg_rmse = rmse.mean()
    print "Total k-fold Time taken: " + str(round(time.time() - start_time,2)) + " seconds"    
    return avg_rmse
    
# Computing rmse for 10-fold cross validation    
res = cross_validation(10,n_train)
print "Average rmse for 10-fold cross validation-",res
# Out:
# Time taken: 4.41 seconds
# Time taken: 4.09 seconds
# Time taken: 4.07 seconds
# Time taken: 4.19 seconds
# Time taken: 4.12 seconds
# Time taken: 4.09 seconds
# Time taken: 4.06 seconds
# Time taken: 4.07 seconds
# Time taken: 4.07 seconds
# Time taken: 4.06 seconds
# Total k-fold Time taken: 41.32 seconds
# Average rmse for 10-fold cross validation- 0.575328105455

# %% [markdown]
# ### 3.6 K-Nearest Neighbors Algorithm
#
# Implement the K-Nearest Neighbors algorithm.  Using 10-fold cross validation, report the RMSE for K=3 and the running time of the algorithm.

# %%
"""
Function
--------
knn

Given a training dataset, test dataset, input features, L and K, compute the rmse using K Nearest neighbor algorithm

Parameters
----------
train : Pandas DataFrame
    DataFrame containing the training data

test : Pandas DataFrame
    DataFrame containing the test data

features : list
    list of columns that are used as input features to fit the model

L : int
    numeric value that is used in calculating Euclidean distance
    
K : int
    numeric value indicating the number of neighbors to use for modelling
    
Returns
-------
rmse : int 
    The average rmse value for K-nearest neighbor algorithm

"""

def knn(train,test,features,L,K):    
    start_time = time.time()   
    # initialising rmse value as zero
    rmse = 0.0
    # dataframe to store the distance matrix 
    dist_df = pd.DataFrame(index=test.index,columns=train.index)     
    # Loop to calculate the distance between every datapoiint in test to every datapoint in train 
    for i,rowi in test.iterrows():       
        for j,rowj in train.iterrows():           
            dist_df.ix[i,j] = distance(list(rowi[features]),list(rowj[features]),L)       
            
    # dataframe to store K nearest neighbors
    min_arr = pd.DataFrame(index=test.index,columns=range(K))  
    y_est = pd.Series(index=test.index)
    # loop to compute the K neighbors based on ascedning distance 
    for i,row in dist_df.iterrows():    
        r = row.sort_values()       
        min_arr.ix[i,:] = pd.Series(r[:K].index)        
    # loop for calculating the mean of the K-nearest neighbors as predicted values
    for i,row in min_arr.iterrows():      
        y_est.ix[i] = train.ix[row,'medv'].mean()
       
    y_true = test.medv.copy()   
    # computing rmse 
    rmse = compute_rmse(np.array(y_est),np.array(y_true))    
    print "Time taken: " + str(round(time.time() - start_time,2)) + " seconds"      
    return rmse

# %%
"""
Function
--------
knn_cross_validation

Given a data and kfold value, perform the k-fold cross validation on the data

Parameters
----------
kfold : int
    numeric value indicating the number of folds for cross validation

data : Pandas DataFrame
    DataFrame containing training dataset

features : list
    list of columns that are used as input features to fit the model

L : int
    numeric value that is used in calculating Euclidean distance
    
K : int
    numeric value indicating the number of neighbors to use for modelling
    
Returns
-------
avg_rmse : int 
    The average rmse value across k-fold cross validation

"""
def knn_cross_validation(kfold,data,features,L,K):
    start_time = time.time()    
    # series for storing rmse for each fold
    rmse = pd.Series(index=range(kfold))
    # Finding the number of values in each subsample
    n = (len(data))/kfold       
        
    d = data.copy()
    # Choosing only the number of rows that are evenly divided within train and test dataset 
    # Ignoring a few datapoints so that each subsample has equal number of datapoints
    d = data.head(n*kfold)    
    # Dataframe for storing the indexes for each subsample as a row    
    subsamples = pd.DataFrame(index=range(kfold),columns=range(n))    
    
    ind = pd.Series(d.index.values.copy())    
    # Randomly shuffling indexes
    np.random.shuffle(ind)       
    i=0   
    rowi = 0
    # Loop to create each row as a subsample
    while((i+n)<len(data)):
        subsamples.iloc[rowi,:] = list(ind.iloc[i:(i+n)])
        i = i+n
        rowi = rowi+1         
    
    for i in range(kfold):
        # choosing one of the subsample as test
        test_ind = subsamples.iloc[i,:]       
        # finding indexes that are not in test
        b = set(test_ind)
        c = set(d.index)
        a = c.difference(b)
        # creating the train and test dataset
        train = d.ix[a,:].copy()
        test = d.ix[b,:].copy()    
        
        # computing rmse using K-nearest neighbors
        n = knn(train,test,features,L,K) 
        # storing rmse for each fold
        rmse = rmse.set_value(i, n)  
    
    # computing average rmse across k-fold
    avg_rmse = rmse.mean()
    print "Total k-fold Time taken: " + str(round(time.time() - start_time,2)) + " seconds"    
    return avg_rmse

# Computing 10-fold cross validation using crim and rm as input features
cvk = knn_cross_validation(10,n_train,[0,5],2,3)
print "Average rmse for 10-fold cross validation with K as 3 -",cvk
# Out:
# Time taken: 4.13 seconds
# Time taken: 4.06 seconds
# Time taken: 4.16 seconds
# Time taken: 4.36 seconds
# Time taken: 4.32 seconds
# Time taken: 4.16 seconds
# Time taken: 4.18 seconds
# Time taken: 4.16 seconds
# Time taken: 4.34 seconds
# Time taken: 4.16 seconds
# Total k-fold Time taken: 42.11 seconds
# Average rmse for 10-fold cross validation with K as 3 - 0.533101035388

# %% [markdown]
# ### 3.7 Using cross validation to find K
#
# What is the best choice of K?  Compute the RMSE for values of K between 1 and 25 using 10-fold cross-validation.  Use the following features in your model, and don't forget to normalize: CRIM, ZN, RM, AGE, DIS, TAX.  Create a graph that shows how RMSE changes as K increases from 1 to 25.  Label your axes, and summarize what you see.  What do you think is a reasonable choice of K for this model?

# %%
start_time = time.time()
# series to store rmse for each value of K
rmse = pd.Series(index=range(1,26))
# loop to compute average rmse for 10-fold cross validation
for K in range(1,26):
    rmse.ix[K] = knn_cross_validation(10,n_train,[0,1,5,6,7,9],2,K)
    print "rmse ",K,rmse.ix[K]
print "K value for lowest rmse - ",rmse.idxmin()    

print "Total Time taken for finding optimum K: " + str(round(time.time() - start_time,2)) + " seconds"
# Out:
# Time taken: 4.26 seconds
# Time taken: 4.2 seconds
# Time taken: 4.69 seconds
# Time taken: 5.25 seconds
# Time taken: 4.64 seconds
# Time taken: 4.18 seconds
# Time taken: 4.11 seconds
# Time taken: 4.1 seconds
# Time taken: 4.13 seconds
# Time taken: 4.1 seconds
# Total k-fold Time taken: 43.7 seconds
# rmse  1 0.561754227199
# Time taken: 4.09 seconds
# Time taken: 4.11 seconds
# Time taken: 4.14 seconds
# Time taken: 4.13 seconds
# Time taken: 4.12 seconds
# Time taken: 4.83 seconds
# Time taken: 5.58 seconds
# Time taken: 5.16 seconds
# Time taken: 5.19 seconds
# Time taken: 4.7 seconds
# Total k-fold Time taken: 46.1 seconds
# rmse  2 0.514508409186
# Time taken: 4.99 seconds
# Time taken: 4.75 seconds
# Time taken: 4.59 seconds
# Time taken: 4.95 seconds
# Time taken: 4.81 seconds
# Time taken: 4.56 seconds
# Time taken: 4.8 seconds
# Time taken: 5.0 seconds
# Time taken: 4.32 seconds
# Time taken: 4.65 seconds
# Total k-fold Time taken: 47.51 seconds
# rmse  3 0.500455898068
# Time taken: 4.58 seconds
# Time taken: 4.14 seconds
# Time taken: 4.53 seconds
# Time taken: 4.27 seconds
# Time taken: 4.21 seconds
# Time taken: 4.32 seconds
# Time taken: 4.48 seconds
# Time taken: 4.49 seconds
# Time taken: 5.36 seconds
# Time taken: 4.85 seconds
# Total k-fold Time taken: 45.34 seconds
# rmse  4 0.503977671759
# Time taken: 5.22 seconds
# Time taken: 5.18 seconds
# Time taken: 4.23 seconds
# Time taken: 4.21 seconds
# Time taken: 4.12 seconds
# Time taken: 4.2 seconds
# Time taken: 4.7 seconds
# Time taken: 4.23 seconds
# Time taken: 4.42 seconds
# Time taken: 4.3 seconds
# Total k-fold Time taken: 44.88 seconds
# rmse  5 0.514401326935
# Time taken: 4.3 seconds
# Time taken: 4.27 seconds
# Time taken: 4.3 seconds
# Time taken: 4.31 seconds
# Time taken: 4.3 seconds
# Time taken: 4.37 seconds
# Time taken: 4.41 seconds
# Time taken: 4.49 seconds
# Time taken: 4.49 seconds
# Time taken: 4.48 seconds
# Total k-fold Time taken: 43.83 seconds
# rmse  6 0.504811633833
# Time taken: 4.57 seconds
# Time taken: 4.49 seconds
# Time taken: 4.61 seconds
# Time taken: 4.59 seconds
# Time taken: 4.65 seconds
# Time taken: 4.66 seconds
# Time taken: 4.67 seconds
# Time taken: 4.73 seconds
# Time taken: 4.76 seconds
# Time taken: 4.86 seconds
# Total k-fold Time taken: 46.68 seconds
# rmse  7 0.505088346791
# Time taken: 4.8 seconds
# Time taken: 4.85 seconds
# Time taken: 5.85 seconds
# Time taken: 5.33 seconds
# Time taken: 4.92 seconds
# Time taken: 4.93 seconds
# Time taken: 4.93 seconds
# Time taken: 4.92 seconds
# Time taken: 4.94 seconds
# Time taken: 4.96 seconds
# Total k-fold Time taken: 50.53 seconds
# rmse  8 0.518389063239
# Time taken: 4.95 seconds
# Time taken: 4.94 seconds
# Time taken: 4.95 seconds
# Time taken: 4.92 seconds
# Time taken: 4.8 seconds
# Time taken: 4.86 seconds
# Time taken: 4.83 seconds
# Time taken: 4.99 seconds
# Time taken: 5.5 seconds
# Time taken: 5.01 seconds
# Total k-fold Time taken: 49.87 seconds
# rmse  9 0.511169503171
# Time taken: 4.79 seconds
# Time taken: 4.76 seconds
# Time taken: 4.73 seconds
# Time taken: 4.67 seconds
# Time taken: 4.63 seconds
# Time taken: 4.7 seconds
# Time taken: 4.65 seconds
# Time taken: 5.41 seconds
# Time taken: 5.04 seconds
# Time taken: 4.63 seconds
# Total k-fold Time taken: 48.13 seconds
# rmse  10 0.520607644099
# Time taken: 4.55 seconds
# Time taken: 4.5 seconds
# Time taken: 5.04 seconds
# Time taken: 5.89 seconds
# Time taken: 5.36 seconds
# Time taken: 5.29 seconds
# Time taken: 5.17 seconds
# Time taken: 6.45 seconds
# Time taken: 5.15 seconds
# Time taken: 5.25 seconds
# Total k-fold Time taken: 52.74 seconds
# rmse  11 0.524024175521
# Time taken: 5.03 seconds
# Time taken: 4.58 seconds
# Time taken: 4.54 seconds
# Time taken: 4.58 seconds
# Time taken: 4.49 seconds
# Time taken: 4.57 seconds
# Time taken: 4.92 seconds
# Time taken: 5.32 seconds
# Time taken: 6.05 seconds
# Time taken: 4.75 seconds
# Total k-fold Time taken: 48.88 seconds
# rmse  12 0.528367888925
# Time taken: 5.44 seconds
# Time taken: 4.42 seconds
# Time taken: 4.39 seconds
# Time taken: 4.56 seconds
# Time taken: 4.56 seconds
# Time taken: 4.35 seconds
# Time taken: 4.55 seconds
# Time taken: 4.49 seconds
# Time taken: 4.73 seconds
# Time taken: 4.67 seconds
# Total k-fold Time taken: 46.23 seconds
# rmse  13 0.517585811896
# Time taken: 4.63 seconds
# Time taken: 4.48 seconds
# Time taken: 4.44 seconds
# Time taken: 4.63 seconds
# Time taken: 4.6 seconds
# Time taken: 4.42 seconds
# Time taken: 4.55 seconds
# Time taken: 5.47 seconds
# Time taken: 5.29 seconds
# Time taken: 4.65 seconds
# Total k-fold Time taken: 47.21 seconds
# rmse  14 0.532122148501
# Time taken: 4.23 seconds
# Time taken: 4.25 seconds
# Time taken: 4.2 seconds
# Time taken: 4.19 seconds
# Time taken: 4.13 seconds
# Time taken: 4.16 seconds
# Time taken: 4.14 seconds
# Time taken: 4.96 seconds
# Time taken: 4.16 seconds
# Time taken: 4.15 seconds
# Total k-fold Time taken: 42.61 seconds
# rmse  15 0.528001783264
# Time taken: 4.14 seconds
# Time taken: 4.17 seconds
# Time taken: 4.21 seconds
# Time taken: 4.15 seconds
# Time taken: 4.16 seconds
# Time taken: 4.2 seconds
# Time taken: 4.16 seconds
# Time taken: 4.16 seconds
# Time taken: 4.14 seconds
# Time taken: 4.15 seconds
# Total k-fold Time taken: 41.66 seconds
# rmse  16 0.528232786847
# Time taken: 4.16 seconds
# Time taken: 4.16 seconds
# Time taken: 4.17 seconds
# Time taken: 4.14 seconds
# Time taken: 4.19 seconds
# Time taken: 4.15 seconds
# Time taken: 4.12 seconds
# Time taken: 4.17 seconds
# Time taken: 4.15 seconds
# Time taken: 4.17 seconds
# Total k-fold Time taken: 41.66 seconds
# rmse  17 0.531041581493
# Time taken: 4.14 seconds
# Time taken: 4.16 seconds
# Time taken: 4.14 seconds
# Time taken: 4.13 seconds
# Time taken: 4.16 seconds
# Time taken: 4.23 seconds
# Time taken: 5.08 seconds
# Time taken: 4.14 seconds
# Time taken: 4.31 seconds
# Time taken: 4.2 seconds
# Total k-fold Time taken: 42.72 seconds
# rmse  18 0.553773989803
# Time taken: 4.15 seconds
# Time taken: 4.17 seconds
# Time taken: 4.12 seconds
# Time taken: 4.18 seconds
# Time taken: 4.15 seconds
# Time taken: 4.15 seconds
# Time taken: 4.14 seconds
# Time taken: 4.16 seconds
# Time taken: 4.18 seconds
# Time taken: 4.19 seconds
# Total k-fold Time taken: 41.66 seconds
# rmse  19 0.556365654698
# Time taken: 4.21 seconds
# Time taken: 4.23 seconds
# Time taken: 4.2 seconds
# Time taken: 4.18 seconds
# Time taken: 4.19 seconds
# Time taken: 4.22 seconds
# Time taken: 4.24 seconds
# Time taken: 4.52 seconds
# Time taken: 4.26 seconds
# Time taken: 4.25 seconds
# Total k-fold Time taken: 42.57 seconds
# rmse  20 0.55360125225
# Time taken: 4.23 seconds
# Time taken: 4.23 seconds
# Time taken: 4.24 seconds
# Time taken: 4.29 seconds
# Time taken: 5.18 seconds
# Time taken: 4.25 seconds
# Time taken: 4.26 seconds
# Time taken: 4.28 seconds
# Time taken: 4.27 seconds
# Time taken: 4.27 seconds
# Total k-fold Time taken: 43.53 seconds
# rmse  21 0.570793950016
# Time taken: 4.25 seconds
# Time taken: 4.25 seconds
# Time taken: 4.26 seconds
# Time taken: 4.21 seconds
# Time taken: 4.26 seconds
# Time taken: 4.23 seconds
# Time taken: 4.26 seconds
# Time taken: 4.27 seconds
# Time taken: 4.25 seconds
# Time taken: 4.26 seconds
# Total k-fold Time taken: 42.58 seconds
# rmse  22 0.565914271842
# Time taken: 4.23 seconds
# Time taken: 4.28 seconds
# Time taken: 4.24 seconds
# Time taken: 4.27 seconds
# Time taken: 4.24 seconds
# Time taken: 4.26 seconds
# Time taken: 4.27 seconds
# Time taken: 4.24 seconds
# Time taken: 4.28 seconds
# Time taken: 4.28 seconds
# Total k-fold Time taken: 42.6 seconds
# rmse  23 0.561558473946
# Time taken: 4.26 seconds
# Time taken: 4.41 seconds
# Time taken: 5.21 seconds
# Time taken: 4.35 seconds
# Time taken: 4.29 seconds
# Time taken: 4.54 seconds
# Time taken: 5.48 seconds
# Time taken: 4.88 seconds
# Time taken: 4.28 seconds
# Time taken: 4.28 seconds
# Total k-fold Time taken: 46.02 seconds
# rmse  24 0.566908324144
# Time taken: 4.26 seconds
# Time taken: 4.3 seconds
# Time taken: 4.28 seconds
# Time taken: 4.3 seconds
# Time taken: 4.29 seconds
# Time taken: 4.3 seconds
# Time taken: 4.37 seconds
# Time taken: 4.32 seconds
# Time taken: 4.34 seconds
# Time taken: 4.34 seconds
# Total k-fold Time taken: 43.22 seconds
# rmse  25 0.572222433707
# K value for lowest rmse -  3
# Total Time taken for finding optimum K: 1132.49 seconds

# %%
K = list(range(1,26))
# Setting figure size
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18, 10)
# Figure showing how RMSE changes when K increases from 1 to 25
plot(K, rmse, 'g*-')
xlabel('K value')
ylabel('RMSE')
title('RMSE Vs K')
show()

# %% [markdown]
# The plot above shows that rmse decreases from 1 to 4 and has an overall positive slope from 5 to 25. Looking at the plot, we can say that a reasonable choice for K is 4 as that is when rmse is the lowest.
